# %% [markdown]
# <a href="https://colab.research.google.com/github/MoazzemhossainMoazz/EDGE_AI/blob/main/Data_Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data = pd.read_csv('/content/drive/MyDrive/dataset-examples-for-presentation-20230904T084118Z-001/dataset-examples-for-presentation/data-example2.csv')

# %%
data
# Out:
#     x1  x2   x3  x4    x5    x6         x7
# 0  1.0   2  5.0   0   4.0   NaN         10
# 1  1.0  15  NaN   1  16.0   2.0          ?
# 2  NaN   3  1.0   2   3.2   4.0          2
# 3  5.0   4  6.0   8   1.0   NaN          ?
# 4  7.0   3  NaN   6   5.0  15.0          3
# 5  2.0   1  6.0   1   1.0   3.0  UNDEFINED

# %%
data = pd.read_csv('/content/drive/MyDrive/dataset-examples-for-presentation-20230904T084118Z-001/dataset-examples-for-presentation/data-example2.csv', na_values=['?', 'UNDEFINED'])

# %%
data
# Out:
#     x1  x2   x3  x4    x5    x6    x7
# 0  1.0   2  5.0   0   4.0   NaN  10.0
# 1  1.0  15  NaN   1  16.0   2.0   NaN
# 2  NaN   3  1.0   2   3.2   4.0   2.0
# 3  5.0   4  6.0   8   1.0   NaN   NaN
# 4  7.0   3  NaN   6   5.0  15.0   3.0
# 5  2.0   1  6.0   1   1.0   3.0   NaN

# %%
data.dtypes
# Out:
# x1    float64
# x2      int64
# x3    float64
# x4      int64
# x5    float64
# x6    float64
# x7    float64
# dtype: object

# %% [markdown]
# #Now we get the data from dataset data-example3

# %%
data = pd.read_csv('/content/drive/MyDrive/dataset-examples-for-presentation-20230904T084118Z-001/dataset-examples-for-presentation/data-example3.csv')

# %%
data
# Out:
#      x1  x2    x3    x4  x5  x6
# 0  10.0   1   4.0   7.0   3   2
# 1  20.0  12   NaN  12.0   4   5
# 2   NaN   5  15.0  12.0   3   6
# 3  40.0   1   6.0   NaN  44   0
# 4  50.0   2  12.0  12.0   3   1
# 5  60.0   4   6.0  17.0   5   4

# %%
data.isnull()
# Out:
#       x1     x2     x3     x4     x5     x6
# 0  False  False  False  False  False  False
# 1  False  False   True  False  False  False
# 2   True  False  False  False  False  False
# 3  False  False  False   True  False  False
# 4  False  False  False  False  False  False
# 5  False  False  False  False  False  False

# %%
mask = data.isnull()

mask.any(axis=1)
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4    False
# 5    False
# dtype: bool

# %%
mask = data.isnull().any(axis=1)
data[mask]
# Out:
#      x1  x2    x3    x4  x5  x6
# 1  20.0  12   NaN  12.0   4   5
# 2   NaN   5  15.0  12.0   3   6
# 3  40.0   1   6.0   NaN  44   0

# %%
mask = data.isnull().any(axis=1)
data[~mask]
# Out:
#      x1  x2    x3    x4  x5  x6
# 0  10.0   1   4.0   7.0   3   2
# 4  50.0   2  12.0  12.0   3   1
# 5  60.0   4   6.0  17.0   5   4

# %%
mask = data.isnull().any(axis=0)
mask
# Out:
# x1     True
# x2    False
# x3     True
# x4     True
# x5    False
# x6    False
# dtype: bool

# %%
data
# Out:
#      x1  x2    x3    x4  x5  x6
# 0  10.0   1   4.0   7.0   3   2
# 1  20.0  12   NaN  12.0   4   5
# 2   NaN   5  15.0  12.0   3   6
# 3  40.0   1   6.0   NaN  44   0
# 4  50.0   2  12.0  12.0   3   1
# 5  60.0   4   6.0  17.0   5   4

# %%
mask = data.isnull().any(axis=0)
data.columns[mask]
# Out:
# Index(['x1', 'x3', 'x4'], dtype='object')

# %%
mask = data.isnull().any(axis=0)

cols_with_nan = data.columns[mask]

data[cols_with_nan]
# Out:
#      x1    x3    x4
# 0  10.0   4.0   7.0
# 1  20.0   NaN  12.0
# 2   NaN  15.0  12.0
# 3  40.0   6.0   NaN
# 4  50.0  12.0  12.0
# 5  60.0   6.0  17.0

# %%
mask = data.isnull().any(axis=0)

cols_without_nan = data.columns[~mask]

data[cols_without_nan]
# Out:
#    x2  x5  x6
# 0   1   3   2
# 1  12   4   5
# 2   5   3   6
# 3   1  44   0
# 4   2   3   1
# 5   4   5   4

# %% [markdown]
# #Now we get the data from dataset data-example4

# %%
data = pd.read_csv('/content/drive/MyDrive/dataset-examples-for-presentation-20230904T084118Z-001/dataset-examples-for-presentation/data-example4.csv')

# %%
data
# Out:
#        x1  x2  x3    x4  x5  x6
# 0    10.0   1   4   7.0   3   2
# 1    20.0  12   5  12.0   4   5
# 2     NaN   5  15  12.0   3   6
# 3    40.0   1   6   3.0  44   0
# 4    50.0   2  12   7.0   3   1
# 5    60.0   4   6  17.0   5   4
# 6    70.0   5   4   7.0   3   2
# 7    80.0  21   5  12.0   4   5
# 8    90.0   5  15  12.0   3   6
# 9   100.0  17   6   NaN  44   0
# 10  110.0   2  14  20.0   3   1
# 11  120.0   4   6  17.0   5   4
# 12  130.0   1   4   7.0   3   2
# 13  140.0  12   5  12.0   4   5
# 14  150.0   5  15  12.0   3   6
# 15  160.0   1   6   3.0  44   0
# 16  170.0   2  12  12.0   3   1
# 17  180.0   4   6  17.0   5   4
# 18  181.0   1   6   3.0  44   0
# 19  182.0   2  12   3.0   3   1
# 20  183.0   4   6  17.0   5   4
# 21  184.0   5   4   7.0   3   2
# 22  185.0  21   5  12.0   4   5
# 23  186.0   5  15  12.0   3   6
# 24  187.0  17   6   3.0  44   0
# 25  188.0   2  14  20.0   3   1
# 26  189.0   4   6  17.0   5   4
# 27  190.0   1   4   7.0   3   2
# ...

# %%
data.head()
# Out:
#      x1  x2  x3    x4  x5  x6
# 0  10.0   1   4   7.0   3   2
# 1  20.0  12   5  12.0   4   5
# 2   NaN   5  15  12.0   3   6
# 3  40.0   1   6   3.0  44   0
# 4  50.0   2  12   7.0   3   1

# %%
data.head()

mask = data.isnull().any(axis=1)

mask
# Out:
# 0     False
# 1     False
# 2      True
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9      True
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# dtype: bool

# %%
data.head()

mask = data.isnull().any(axis=1)

num_of_rows_with_nan = mask.sum()
total_num_of_rows = len(data)

num_of_rows_with_nan/total_num_of_rows
# Out:
# 0.06060606060606061

# %%
data.head()

mask = data.isnull().any(axis=1)

num_of_rows_with_nan = mask.sum()
total_num_of_rows = len(data)

data_clean1 = data[mask]
data_clean1
# Out:
#       x1  x2  x3    x4  x5  x6
# 2    NaN   5  15  12.0   3   6
# 9  100.0  17   6   NaN  44   0

# %%
data.head()

mask = data.isnull().any(axis=1)

num_of_rows_with_nan = mask.sum()
total_num_of_rows = len(data)

data_clean2 = data[~mask]
data_clean2
# Out:
#        x1  x2  x3    x4  x5  x6
# 0    10.0   1   4   7.0   3   2
# 1    20.0  12   5  12.0   4   5
# 3    40.0   1   6   3.0  44   0
# 4    50.0   2  12   7.0   3   1
# 5    60.0   4   6  17.0   5   4
# 6    70.0   5   4   7.0   3   2
# 7    80.0  21   5  12.0   4   5
# 8    90.0   5  15  12.0   3   6
# 10  110.0   2  14  20.0   3   1
# 11  120.0   4   6  17.0   5   4
# 12  130.0   1   4   7.0   3   2
# 13  140.0  12   5  12.0   4   5
# 14  150.0   5  15  12.0   3   6
# 15  160.0   1   6   3.0  44   0
# 16  170.0   2  12  12.0   3   1
# 17  180.0   4   6  17.0   5   4
# 18  181.0   1   6   3.0  44   0
# 19  182.0   2  12   3.0   3   1
# 20  183.0   4   6  17.0   5   4
# 21  184.0   5   4   7.0   3   2
# 22  185.0  21   5  12.0   4   5
# 23  186.0   5  15  12.0   3   6
# 24  187.0  17   6   3.0  44   0
# 25  188.0   2  14  20.0   3   1
# 26  189.0   4   6  17.0   5   4
# 27  190.0   1   4   7.0   3   2
# 28  191.0  12   5  12.0   4   5
# 29  192.0   5  15  12.0   3   6
# ...

# %%
print(data_clean1 / data_clean2)
# Out:
#     x1  x2  x3  x4  x5  x6
# 0  NaN NaN NaN NaN NaN NaN
# 1  NaN NaN NaN NaN NaN NaN
# 2  NaN NaN NaN NaN NaN NaN
# 3  NaN NaN NaN NaN NaN NaN
# 4  NaN NaN NaN NaN NaN NaN
# 5  NaN NaN NaN NaN NaN NaN
# 6  NaN NaN NaN NaN NaN NaN
# 7  NaN NaN NaN NaN NaN NaN
# 8  NaN NaN NaN NaN NaN NaN
# 9  NaN NaN NaN NaN NaN NaN
# 10 NaN NaN NaN NaN NaN NaN
# 11 NaN NaN NaN NaN NaN NaN
# 12 NaN NaN NaN NaN NaN NaN
# 13 NaN NaN NaN NaN NaN NaN
# 14 NaN NaN NaN NaN NaN NaN
# 15 NaN NaN NaN NaN NaN NaN
# 16 NaN NaN NaN NaN NaN NaN
# 17 NaN NaN NaN NaN NaN NaN
# 18 NaN NaN NaN NaN NaN NaN
# 19 NaN NaN NaN NaN NaN NaN
# 20 NaN NaN NaN NaN NaN NaN
# 21 NaN NaN NaN NaN NaN NaN
# 22 NaN NaN NaN NaN NaN NaN
# 23 NaN NaN NaN NaN NaN NaN
# 24 NaN NaN NaN NaN NaN NaN
# 25 NaN NaN NaN NaN NaN NaN
# 26 NaN NaN NaN NaN NaN NaN
# 27 NaN NaN NaN NaN NaN NaN
# 28 NaN NaN NaN NaN NaN NaN
# 29 NaN NaN NaN NaN NaN NaN
# 30 NaN NaN NaN NaN NaN NaN
# 31 NaN NaN NaN NaN NaN NaN
# 32 NaN NaN NaN NaN NaN NaN

# %%
data = pd.read_csv('/content/drive/MyDrive/dataset-examples-for-presentation-20230904T084118Z-001/dataset-examples-for-presentation/data-example5.csv')

# %%
data.head()

mask = data.isnull().any(axis=1)

num_of_rows_with_nan = mask.sum()
total_num_of_rows = len(data)

print(num_of_rows_with_nan/total_num_of_rows)
# Out:
# 0.5454545454545454

# %%
data.isnull()
# Out:
#        x1     x2     x3     x4     x5     x6
# 0   False  False   True  False  False  False
# 1   False  False  False  False  False  False
# 2    True  False   True  False  False  False
# 3   False  False   True  False  False  False
# 4   False  False  False  False  False  False
# 5   False  False   True  False  False  False
# 6   False  False  False  False  False  False
# 7   False  False   True  False  False  False
# 8   False  False   True  False  False  False
# 9   False  False   True   True  False  False
# 10  False  False  False  False  False  False
# 11  False  False  False  False  False  False
# 12  False  False  False  False  False  False
# 13  False  False   True   True  False  False
# 14  False  False  False  False  False  False
# 15  False  False  False  False  False  False
# 16  False  False   True  False  False  False
# 17  False  False  False  False  False  False
# 18  False  False  False  False  False  False
# 19  False  False   True  False  False  False
# ...

# %%
data.isnull().sum()
# Out:
# x1     1
# x2     0
# x3    18
# x4     2
# x5     0
# x6     0
# dtype: int64

# %%
data.isnull().sum()/len(data)
# Out:
# x1    0.030303
# x2    0.000000
# x3    0.545455
# x4    0.060606
# x5    0.000000
# x6    0.000000
# dtype: float64

# %%
data.head()
# Out:
#      x1  x2    x3    x4  x5  x6
# 0  10.0   1   NaN   7.0   3   2
# 1  20.0  12   5.0  12.0   4   5
# 2   NaN   5   NaN  12.0   3   6
# 3  40.0   1   NaN   3.0  44   0
# 4  50.0   2  12.0   7.0   3   1

# %%
data.head()

data_without_x3 = data.drop(columns=['x3'])

data_without_x3
# Out:
#        x1  x2    x4  x5  x6
# 0    10.0   1   7.0   3   2
# 1    20.0  12  12.0   4   5
# 2     NaN   5  12.0   3   6
# 3    40.0   1   3.0  44   0
# 4    50.0   2   7.0   3   1
# 5    60.0   4  17.0   5   4
# 6    70.0   5   7.0   3   2
# 7    80.0  21  12.0   4   5
# 8    90.0   5  12.0   3   6
# 9   100.0  17   NaN  44   0
# 10  110.0   2  20.0   3   1
# 11  120.0   4  17.0   5   4
# 12  130.0   1   7.0   3   2
# 13  140.0  12   NaN   4   5
# 14  150.0   5  12.0   3   6
# 15  160.0   1   3.0  44   0
# 16  170.0   2  12.0   3   1
# 17  180.0   4  17.0   5   4
# 18  181.0   1   3.0  44   0
# 19  182.0   2   3.0   3   1
# 20  183.0   4  17.0   5   4
# 21  184.0   5   7.0   3   2
# 22  185.0  21  12.0   4   5
# 23  186.0   5  12.0   3   6
# 24  187.0  17   3.0  44   0
# 25  188.0   2  20.0   3   1
# 26  189.0   4  17.0   5   4
# 27  190.0   1   7.0   3   2
# 28  191.0  12  12.0   4   5
# 29  192.0   5  12.0   3   6
# 30  193.0   1   3.0  44   0
# 31  194.0   2  12.0   3   1
# ...

# %%
data.head()

data_without_x3 = data.drop(columns=['x3'])

mask = data_without_x3.isnull().any(axis=1)

mask
# Out:
# 0     False
# 1     False
# 2      True
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9      True
# 10    False
# 11    False
# 12    False
# 13     True
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# dtype: bool

# %%
mask.sum()
# Out:
# 3

# %%
len(data_without_x3)
# Out:
# 33

# %%
n_rows_with_nan = mask.sum()

n_rows_with_nan / len(data_without_x3)
# Out:
# 0.09090909090909091

# %%
n_rows_with_nan = mask.sum()

n_rows_with_nan / len(data_without_x3)
data_clean = data_without_x3[~mask]

data_clean
# Out:
#        x1  x2    x4  x5  x6
# 0    10.0   1   7.0   3   2
# 1    20.0  12  12.0   4   5
# 3    40.0   1   3.0  44   0
# 4    50.0   2   7.0   3   1
# 5    60.0   4  17.0   5   4
# 6    70.0   5   7.0   3   2
# 7    80.0  21  12.0   4   5
# 8    90.0   5  12.0   3   6
# 10  110.0   2  20.0   3   1
# 11  120.0   4  17.0   5   4
# 12  130.0   1   7.0   3   2
# 14  150.0   5  12.0   3   6
# 15  160.0   1   3.0  44   0
# 16  170.0   2  12.0   3   1
# 17  180.0   4  17.0   5   4
# 18  181.0   1   3.0  44   0
# 19  182.0   2   3.0   3   1
# 20  183.0   4  17.0   5   4
# 21  184.0   5   7.0   3   2
# 22  185.0  21  12.0   4   5
# 23  186.0   5  12.0   3   6
# 24  187.0  17   3.0  44   0
# 25  188.0   2  20.0   3   1
# 26  189.0   4  17.0   5   4
# 27  190.0   1   7.0   3   2
# 28  191.0  12  12.0   4   5
# 29  192.0   5  12.0   3   6
# 30  193.0   1   3.0  44   0
# 31  194.0   2  12.0   3   1
# 32  195.0   4  17.0   5   4

# %%
data.head()
# Out:
#      x1  x2    x3    x4  x5  x6
# 0  10.0   1   NaN   7.0   3   2
# 1  20.0  12   5.0  12.0   4   5
# 2   NaN   5   NaN  12.0   3   6
# 3  40.0   1   NaN   3.0  44   0
# 4  50.0   2  12.0   7.0   3   1

# %%
data_2 = data.fillna(0.0)

data_2.head()
# Out:
#      x1  x2    x3    x4  x5  x6
# 0  10.0   1   0.0   7.0   3   2
# 1  20.0  12   5.0  12.0   4   5
# 2   0.0   5   0.0  12.0   3   6
# 3  40.0   1   0.0   3.0  44   0
# 4  50.0   2  12.0   7.0   3   1

# %%
data_2 = data.fillna({'x1': 0.1, 'x3': 0.0})

data_2.head()
# Out:
#      x1  x2    x3    x4  x5  x6
# 0  10.0   1   0.0   7.0   3   2
# 1  20.0  12   5.0  12.0   4   5
# 2   0.1   5   0.0  12.0   3   6
# 3  40.0   1   0.0   3.0  44   0
# 4  50.0   2  12.0   7.0   3   1

# %%
data_2 = data.fillna({'x1': 'NaN', 'x3': 'NaN'})

data_2.head()
# Out:
#      x1  x2    x3    x4  x5  x6
# 0  10.0   1   NaN   7.0   3   2
# 1  20.0  12   5.0  12.0   4   5
# 2   NaN   5   NaN  12.0   3   6
# 3  40.0   1   NaN   3.0  44   0
# 4  50.0   2  12.0   7.0   3   1

# %%
col_means = data.mean(axis=0)

col_means
# Out:
# x1    140.625000
# x2      5.757576
# x3      8.266667
# x4     10.774194
# x5     10.969697
# x6      2.878788
# dtype: float64

# %%
data_2=data.fillna(col_means)

data_2.head()
# Out:
#         x1  x2         x3    x4  x5  x6
# 0   10.000   1   8.266667   7.0   3   2
# 1   20.000  12   5.000000  12.0   4   5
# 2  140.625   5   8.266667  12.0   3   6
# 3   40.000   1   8.266667   3.0  44   0
# 4   50.000   2  12.000000   7.0   3   1

# %%
data.head()
# Out:
#      x1  x2    x3    x4  x5  x6
# 0  10.0   1   NaN   7.0   3   2
# 1  20.0  12   5.0  12.0   4   5
# 2   NaN   5   NaN  12.0   3   6
# 3  40.0   1   NaN   3.0  44   0
# 4  50.0   2  12.0   7.0   3   1

# %% [markdown]
# #Added dataset Example 6

# %%
data = pd.read_csv('/content/drive/MyDrive/dataset-examples-for-presentation-20230904T084118Z-001/dataset-examples-for-presentation/data-example6.csv')

# %%
data.head()
# Out:
#    x1  x2    x3  x4  x5  x6
# 0  10   1   low   7   3   2
# 1  20  12   NaN  12   4   5
# 2  30   5  high  12   3   6
# 3  40   1  high   3  44   0
# 4  50   2   NaN   7   3   1

# %%
data['x3'].mode()
# Out:
# 0    high
# Name: x3, dtype: object

# %%
data['x3'].mode()[0]
# Out:
# 'high'

# %%
most_freq_val = data['x3'].mode()[0]

# %%
data_2 = data.fillna({'x3': most_freq_val})

data_2.head()
# Out:
#    x1  x2    x3  x4  x5  x6
# 0  10   1   low   7   3   2
# 1  20  12  high  12   4   5
# 2  30   5  high  12   3   6
# 3  40   1  high   3  44   0
# 4  50   2  high   7   3   1

# %% [markdown]
# #Categorical Data

# %%
data = pd.read_csv('/content/drive/MyDrive/dataset-examples-for-presentation-20230904T084118Z-001/dataset-examples-for-presentation/data-example7.csv')

# %%
data.head()
# Out:
#        x1  x2    x3          x4  x5  x6
# 0    male   1   low   full-time   3   2
# 1    male  12   med   part-time   4   5
# 2  female   5  high   full-time   3   6
# 3    male   1  high  unemployed  44   0
# 4  female   2   low   part-time   3   1

# %%
most_freq_val = data['x3'].mode()[0]

# %%
data_2 = data.fillna({'x3': most_freq_val})

data_2.head()

# %%
print(data['x1'].unique())
print(data['x3'].unique())
print(data['x4'].unique())

# %%
data.replace({
    'x1' : {'male':0,'female': 1},
    'x3' : {'low':0, 'med':1, 'high': 2},
    'x4' : {'part_time': 0, 'full-time': 1, 'unemployed':2}
})

# %%
col_means = data.mean(axis=0)

col_means
